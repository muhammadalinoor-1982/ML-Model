# %% [markdown]
# # **Spacy for Entity Extraction**

# %% [markdown]
# NER -> Name entity recognition

# %% [markdown]
# ![alt text](https://miro.medium.com/max/1400/1*qQggIPMugLcy-ndJ8X_aAA.png)

# %%
# NER
# Name entity Recognition

# NLP
# Natural language Processing

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm -q
# Out:
# [+] Download and installation successful
# 2023-06-09 22:24:36.457214: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-06-09 22:24:36.457260: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.5.tar.gz

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
doc=nlp('I spent $25 today')
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(I, 'O', ''), (spent, 'O', ''), ($, 'O', ''), (25, 'B', 'MONEY'), (today, 'B', 'DATE')]

# %%
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'), (authorities, 'O', ''), (fined, 'O', ''), (Google, 'B', 'ORG'), (a, 'O', ''), (record, 'O', ''), ($, 'B', 'MONEY'), (5.1, 'I', 'MONEY'), (billion, 'I', 'MONEY'), (on, 'O', ''), (Wednesday, 'B', 'DATE'), (for, 'O', ''), (abusing, 'O', ''), (its, 'O', ''), (power, 'O', ''), (in, 'O', ''), (the, 'O', ''), (mobile, 'O', ''), (phone, 'O', ''), (market, 'O', ''), (and, 'O', ''), (ordered, 'O', ''), (the, 'O', ''), (company, 'O', ''), (to, 'O', ''), (alter, 'O', ''), (its, 'O', ''), (practices, 'O', '')]

# %%
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities fined
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  a record
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $5.1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for abusing its power in the mobile phone market and ordered the company to alter its practices</div></span>

# %%
displacy.render(nlp(str(doc)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="26a047be01ec4403ae33cdc8f3acfbe8-0" class="displacy" width="3410" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">European</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">authorities</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">fined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">record</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">5.1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">billion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Wednesday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">abusing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">power</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">mobile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">phone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">market</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">ordered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">alter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">practices</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26a047be01ec4403ae33cdc8f3acfbe8-0-0" stroke-width="2px" d="M70,422.0 C70,362.0 140.0,362.0 140.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26a047be01ec4403ae33cdc8f3acfbe8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,424.0 L62,412.0 78,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26a047be01ec4403ae33cdc8f3acfbe8-0-1" stroke-width="2px" d="M190,422.0 C1

# %% [markdown]
# # **Sentences written in a certain way makes a huge impact**
# like when a word begins witha capital letter spacy is more likely to identify it correctly

# %%
doc=nlp('Miss. Smritika  book a flight from Mumbai to Indore in india with $3500 at 9am in the morning')
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miss.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Smritika  book a flight from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in india with $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9am in the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </div></span>

# %%
# changed Indore to indore
doc=nlp('Miss. Smritika  book a flight from Mumbai to indore in india with $3500 at 9am in the morning')
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miss.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Smritika  book a flight from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to indore in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  with $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9am in the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </div></span>

# %%
#removed 'in india'
doc=nlp('Miss. Smritika  book a flight from Mumbai to Indore with $3500 at 9am in the morning')
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miss.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Smritika  book a flight from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to Indore with $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9am in the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </div></span>

# %%
# remove 'Miss.' and changed $ to dollars and added ' and scored 100 marks'
doc=nlp('Smritika  book a flight from Mumbai to Indore with 3500 dollar at 9am in the morning and scored 100 marks')
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Smritika  book a flight from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to Indore with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3500 dollar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9am in the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  and scored
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100 marks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
#add 'Sadhukhan
doc=nlp('Smritika Sadhukhan book a flight from Mumbai to Indore in india with $3500 at 9am in the morning')
displacy.render(nlp(str(doc)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Smritika Sadhukhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  book a flight from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in india with $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9am in the morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </div></span>

# %% [markdown]
# # **Using Spacy on web Scraped data**

# %%
pip install html5lib
# Out:
# Collecting html5libNote: you may need to restart the kernel to use updated packages.
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: webencodings in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from html5lib) (0.5.1)
#
# Requirement already satisfied: six>=1.9 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %%
from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.lipsum.com/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 119

# %%
article1= str(article).strip()

# %% [markdown]
# ## Frequency of NER found

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 51,
#          'ORG': 23,
#          'NORP': 7,
#          'GPE': 9,
#          'DATE': 10,
#          'PRODUCT': 2,
#          'LANGUAGE': 2,
#          'CARDINAL': 11,
#          'WORK_OF_ART': 1,
#          'ORDINAL': 2,
#          'TIME': 1})

# %% [markdown]
# ## Most Common NER

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Lorem Ipsum', 19), ('Latin', 4), ('45', 4)]

# %% [markdown]
# # **Visualising a single sentence**

# %%
for x in article.sents:
    print(str(x).replace('  ',''))
# Out:
#  Lorem Ipsum - All the facts - Lipsum generatorՀայերեն Shqip ‫العربية Български Català 中文简体 Hrvatski Česky Dansk Nederlands English Eesti Filipino Suomi Français ქართული Deutsch Ελληνικά ‫עברית हिन्दी Magyar Indonesia Italiano Latviski Lietuviškai македонски Melayu Norsk
# Polski Português Româna Pyccкий Српски Slovenčina Slovenščina Español Svenska ไทย
# Türkçe Українська Tiếng ViệtLorem Ipsum "Neque porro quisquam est qui dolorem ipsum quia dolor sit amet, consectetur, adipisci velit..."
# "There is no one who loves pain itself, who seeks after it and wants to have it, simply because it is pain..."
# What is Lorem Ipsum?
# Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
# It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.
# Why do we use it?
# It is a long established fact that a reader will be distracted by the readable content of a page when looking at its layout.
# The point of using Lorem Ipsum is that it has a more-or-less normal distribution of letters, as opposed to using 'Content here, content here', making it look like readable English.
# Many desktop publishing packages and web page editors now use Lorem Ipsum as their default model text, and a search for 'lorem ipsum' will uncover many web sites still in their infancy.
# Various versions have evolved over the years, sometimes by accident, sometimes on purpose (injected humour and the like).
# Where does it come from?
# Contrary to popular belief, Lorem Ipsum is not simply random text.
# It has roots in a piece of classical Latin literature from 45 BC, making it over 2000 years old.
# Richard McClintock, a Latin professor at Hampden-Sydney College in Virginia, looked up one of the more obscure Latin words, consectetur, from a Lorem Ipsum passage, and going through the cites of the word in classical literature, discovered the undoubtable source.
# Lorem Ipsum comes from sections 1.10.32 and 1.10.33 of "de Finibus Bonorum et Malorum" (The Extremes of Good and Evil) by Cicero, written in 45 BC.
# This book is a treatise on the theory of ethics, very popular during the Renaissance.
# The first line of Lorem Ipsum, "Lorem ipsum dolor sit amet..", comes from a line in section 1.10.32.The standard chunk of Lorem Ipsum used since the 1500s is reproduced below for those interested.
# Sections 1.10.32 and 1.10.33 from "de Finibus Bonorum et Malorum" by Cicero are also reproduced in their exact original form, accompanied by English versions from the 1914 translation by H. Rackham.
# Where can I get some?
# There are many variations of passages of Lorem Ipsum available, but the majority have suffered alteration in some form, by injected humour, or randomised words which don't look even slightly believable.
# If you are going to use a passage of Lorem Ipsum, you need to be sure there isn't anything embarrassing hidden in the middle of text.
# All the Lorem Ipsum generators on the Internet tend to repeat predefined chunks as necessary, making this the first true generator on the Internet.
# It uses a dictionary of over 200 Latin words, combined with a handful of model sentence structures, to generate Lorem Ipsum which looks reasonable.
# The generated Lorem Ipsum is therefore always free from repetition, injected humour, or non-characteristic words etc. paragraphswordsbyteslistsStart with 'Loremipsum dolor sit amet...'
# Donate: If you use this site regularly and would like to help keep the site on the Internet, please consider donating a small sum to help pay for the hosting and bandwidth bill.
# There is no minimum donation, any sum is appreciated - click here to donate using PayPal.
# Thank you for your support.
# Donate bitcoin:
# 16UQLq1HZ3CNwhvgrarV6pMoA2CDjb4tyF Translations: Can you help translate this site into a foreign language ?
# Please email us with details if you can help.
# There is a set of mock banners available here in three colours and in a range of standard banner sizes: NodeJS Python Interface GTK Lipsum Rails .NET
# The standard Lorem Ipsum passage, used since the 1500s"Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
# Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur.
# Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# "Section
# 1.10.32 of "de Finibus Bonorum et Malorum", written by Cicero in 45 BC"Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam, eaque ipsa quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt explicabo.
# Nemo enim ipsam voluptatem quia voluptas sit aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos qui ratione voluptatem sequi nesciunt.
# Neque porro quisquam est, qui dolorem ipsum quia dolor sit amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt ut labore et dolore magnam aliquam quaerat voluptatem.
# Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur?
# Quis autem vel eum iure reprehenderit qui in ea voluptate velit esse quam nihil molestiae consequatur, vel illum qui dolorem eum fugiat quo voluptas nulla pariatur?" 1914 translation by H. Rackham "But I must explain to you how all this mistaken idea of denouncing pleasure and praising pain was born and I will give you a complete account of the system, and expound the actual teachings of the great explorer of the truth, the master-builder of human happiness.
# No one rejects, dislikes, or avoids pleasure itself, because it is pleasure, but because those who do not know how to pursue pleasure rationally encounter consequences that are extremely painful.
# Nor again is there anyone who loves or pursues or desires to obtain pain of itself, because it is pain, but because occasionally circumstances occur in which toil and pain can procure him some great pleasure.
# To take a trivial example, which of us ever undertakes laborious physical exercise, except to obtain some advantage from it?
# But who has any right to find fault with a man who chooses to enjoy a pleasure that has no annoying consequences, or one who avoids a pain that produces no resultant pleasure?"
# Section 1.10.33 of "de Finibus Bonorum et Malorum", written by Cicero in 45 BC "At vero eos et accusamus et iusto odio dignissimos ducimus qui blanditiis praesentium voluptatum deleniti atque corrupti quos dolores et quas molestias excepturi sint occaecati cupiditate non provident, similique sunt in culpa qui officia deserunt mollitia animi, id est laborum et dolorum fuga.
# Et harum quidem rerum facilis est et expedita distinctio.
# Nam libero tempore, cum soluta nobis est eligendi optio cumque nihil impedit quo minus id quod maxime placeat facere possimus, omnis voluptas assumenda est, omnis dolor repellendus.
# Temporibus autem quibusdam et aut officiis debitis aut rerum necessitatibus saepe
# eveniet ut et voluptates repudiandae sint et molestiae non recusandae.
# Itaque earum rerum hic tenetur a sapiente delectus, ut aut reiciendis voluptatibus maiores alias consequatur aut perferendis doloribus asperiores repellat."
# 1914 translation by H. Rackham "On the other hand, we denounce with righteous indignation and dislike men who are so beguiled and demoralized by the charms of pleasure of the moment, so blinded by desire, that they cannot foresee the pain and trouble that are bound to ensue; and equal blame belongs to those who fail in their duty through weakness of will, which is the same as saying through shrinking from toil and pain.
# These cases are perfectly simple and easy to distinguish.
# In a free hour, when our power of choice is untrammelled and when nothing prevents our being able to do what we like best, every pleasure is to be welcomed and every pain avoided.
# But in certain circumstances and owing to the claims of duty or the obligations of business it will frequently occur that pleasures have to be repudiated and annoyances accepted.
# The wise man therefore always holds in these matters to this principle of selection: he rejects pleasures to secure other greater pleasures, or else he endures pains to avoid worse pains."
# help@lipsum.comPrivacy Policy · Privacy Manager

# %%
displacy.render(nlp(str(article)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem Ipsum - All
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the facts - Lipsum generator              Հայերեն Shqip ‫العربية
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Български Català
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  中文简体
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hrvatski Česky Dansk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Nederlands English Eesti
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Filipino
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Suomi Français ქართული
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deutsch Ελληνικά
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ‫עברית हिन्दी
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Magyar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Italiano Latviski Lietuviškai македонски Melayu Norsk Polski Português Româna Pyccкий
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Српски
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Slovenčina Slovenščina Español
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Svenska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ไทย
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Türkçe Українська
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Tiếng Việt
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem Ipsum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  &quot;Neque porro quisquam est
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     qui dolorem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ipsum quia dolor sit amet,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     consectetur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adipisci velit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...&quot; &quot;There is no one who loves pain itself, who seeks after it and wants to have it, simply because it is pain...&quot;       What is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem Ipsum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ?
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem Ipsum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is simply dummy text of the printing and typesetting industry.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem Ipsum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has been the industry's standard dummy text ever since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1500s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only five centuries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1960s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with the release of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Letraset
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sheets containing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem Ipsum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  passages, and more recently with desktop publishing software like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aldus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bo

# %%
displacy.render(nlp(str(article)), style='dep', jupyter = True, options = {'distance': 70})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="771925868a3441aca46f8d580c41026f-0" class="displacy" width="100150" height="417.0" direction="ltr" style="max-width: none; height: 417.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">Lorem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">Ipsum -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">All</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">facts -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">Lipsum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">generator</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">             </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Հայերեն</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Shqip</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">‫العربية</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Български</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">Català</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">中文简体</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Hrvatski</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">Česky</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1240">Dansk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">Nederlands</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">English</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Eesti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1520">Filipino</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1520">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">Suomi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1660">Français</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1660">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">ქართული</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Deutsch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">Ελληνικά</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">‫עברית</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">हिन्दी</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2080">Magyar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2080">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Indonesia

# %% [markdown]
# ## **Word with their Lemma form, POS tags and Entity type**

# %%
list1=[y for y in nlp(str(article))]

list1[3].is_stop
# Out:
# False

# %%
for i in list1:
  if i.is_stop:
    print(i)
# Out:
# All
# the
# There
# is
# no
# one
# who
# itself
# who
# after
# it
# and
# to
# have
# it
# because
# it
# is
# What
# is
# is
# of
# the
# and
# has
# been
# the
# 's
# ever
# since
# the
# when
# an
# a
# of
# and
# it
# to
# make
# a
# It
# has
# not
# only
# five
# but
# also
# the
# into
# It
# was
# in
# the
# with
# the
# of
# and
# more
# with
# of
# Why
# do
# we
# it
# It
# is
# a
# that
# a
# will
# be
# by
# the
# of
# a
# when
# at
# its
# The
# of
# using
# is
# that
# it
# has
# a
# more
# or
# less
# of
# as
# to
# using
# here
# here
# it
# Many
# and
# now
# as
# their
# and
# a
# for
# will
# many
# still
# in
# their
# Various
# have
# over
# the
# sometimes
# by
# sometimes
# on
# and
# the
# Where
# does
# it
# from
# to
# is
# not
# It
# has
# in
# a
# of
# from
# it
# over
# a
# at
# in
# up
# one
# of
# the
# more
# from
# a
# and
# through
# the
# of
# the
# in
# the
# from
# and
# of
# The
# of
# and
# by
# in
# This
# is
# a
# on
# the
# of
# very
# during
# the
# The
# first
# of
# from
# a
# in
# of
# used
# since
# the
# is
# below
# for
# those
# and
# from
# by
# are
# also
# in
# their
# by
# from
# the
# by
# Where
# can
# I
# get
# some
# There
# are
# many
# of
# of
# but
# the
# have
# in
# some
# by
# or
# which
# do
# n't
# even
# If
# you
# are
# to
# a
# of
# you
# to
# be
# there
# is
# n't
# anything
# in
# the
# of
# All
# the
# on
# the
# to
# as
# this
# the
# first
# on
# the
# It
# a
# of
# over
# with
# a
# of
# to
# which
# The
# is
# therefore
# always
# from
# or
# with
# If
# you
# this
# and
# would
# to
# keep
# the
# on
# the
# please
# a
# to
# for
# the
# and
# There
# is
# no
# any
# is
# here
# to
# using
# you
# for
# your
# Can
# you
# this
# into
# a
# Please
# us
# with
# if
# you
# can
# There
# is
# a
# of
# here
# in
# three
# and
# in
# a
# of
# The
# used
# since
# the
# do
# in
# in
# in
# i
# of
# by
# in
# in
# by
# But
# I
# must
# to
# you
# how
# all
# this
# of
# and
# was
# and
# I
# will
# give
# you
# a
# of
# the
# and
# the
# of
# the
# of
# the
# the
# of
# No
# one
# or
# itself
# because
# it
# is
# but
# because
# those
# who
# do
# not
# how
# to
# that
# are
# Nor
# again
# is
# there
# anyone
# who
# or
# or
# to
# of
# itself
# because
# it
# is
# but
# because
# in
# which
# and
# can
# him
# some
# To
# take
# a
# which
# of
# us
# ever
# except
# to
# some
# from
# it
# But
# who
# has
# any
# to
# with
# a
# who
# to
# a
# that
# has
# no
# or
# one
# who
# a
# that
# no
# of
# by
# in
# At
# in
# i
# i
# a
# by
# On
# the
# other
# we
# with
# and
# who
# are
# so
# and
# by
# the
# of
# of
# the
# so
# by
# that
# they
# can
# not
# the
# and
# that
# are
# to
# and
# to
# those
# who
# in
# their
# through
# of
# will
# which
# is
# the
# same
# as
# through
# from
# and
# These
# are
# and
# to
# In
# a
# when
# our
# of
# is
# and
# when
# nothing
# our
# being
# to
# do
# what
# we
# every
# is
# to
# be
# and
# every
# But
# in
# and
# to
# the
# of
# or
# the
# of
# it
# will
# that
# have
# to
# be
# and
# The
# therefore
# always
# in
# these
# to
# this
# of
# he
# to
# other
# or
# else
# he
# to

# %%
[(x,x.pos_, x.lemma_,x.ent_type_) for x in [y
                                      for y
                                      in nlp(str(article))
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [( , 'SPACE', ' ', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (facts, 'NOUN', 'fact', ''),
#  (Lipsum, 'PROPN', 'Lipsum', ''),
#  (generator, 'NOUN', 'generator', ''),
#  (             , 'SPACE', '             ', ''),
#  (Հայերեն, 'PROPN', 'Հայերեն', ''),
#  (Shqip, 'PROPN', 'Shqip', ''),
#  (‫العربية, 'PROPN', '\u202bالعربية', ''),
#  (Български, 'PROPN', 'Български', 'ORG'),
#  (Català, 'PROPN', 'Català', 'ORG'),
#  (中文简体, 'ADJ', '中文简体', ''),
#  (Hrvatski, 'PROPN', 'Hrvatski', 'PERSON'),
#  (Česky, 'PROPN', 'Česky', 'PERSON'),
#  (Dansk, 'PROPN', 'Dansk', 'PERSON'),
#  (Nederlands, 'PROPN', 'Nederlands', ''),
#  (English, 'PROPN', 'English', ''),
#  (Eesti, 'PROPN', 'Eesti', ''),
#  (Filipino, 'PROPN', 'Filipino', 'NORP'),
#  (Suomi, 'PROPN', 'Suomi', ''),
#  (Français, 'PROPN', 'Français', ''),
#  (ქართული, 'NOUN', 'ქართული', ''),
#  (Deutsch, 'PROPN', 'Deutsch', 'PERSON'),
#  (Ελληνικά, 'PROPN', 'Ελληνικά', 'PERSON'),
#  (‫עברית, 'PROPN', '\u202bעברית', ''),
#  (हिन्दी, 'NOUN', 'हिन्दी', ''),
#  (Magyar, 'PROPN', 'Magyar', 'GPE'),
#  (Indonesia, 'PROPN', 'Indonesia', 'GPE'),
#  (Italiano, 'PROPN', 'Italiano', ''),
#  (Latviski, 'PROPN', 'Latviski', ''),
#  (Lietuviškai, 'PROPN', 'Lietuviškai', ''),
#  (македонски, 'NOUN', 'македонски', ''),
#  (Melayu, 'PROPN', 'Melayu', ''),
#  (Norsk, 'PROPN', 'Norsk', ''),
#  (Polski, 'PROPN', 'Polski', ''),
#  (Português, 'PROPN', 'Português', ''),
#  (Româna, 'PROPN', 'Româna', ''),
#  (Pyccкий, 'PROPN', 'Pyccкий', ''),
#  (Српски, 'PROPN', 'Српски', 'GPE'),
#  (Slovenčina, 'PROPN', 'Slovenčina', ''),
#  (Slovenščina, 'PROPN', 'Slovenščina', ''),
#  (Español, 'PROPN', 'Español', ''),
#  (Svenska, 'PROPN', 'Svenska', 'GPE'),
#  (ไทย, 'NOUN', 'ไทย', ''),
#  (Türkçe, 'PROPN', 'Türkçe', 'PERSON'),
#  (Українська, 'PROPN', 'Українська', 'PERSON'),
#  (Tiếng, 'PROPN', 'Tiếng', ''),
#  (Việt, 'PROPN', 'Việt', ''),
#  ( , 'SPACE', ' ', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (Neque, 'PROPN', 'Neque', ''),
#  (porro, 'PROPN', 'porro', ''),
#  (quisquam, 'VERB', 'quisquam', ''),
#  (est, 'X', 'est', ''),
#  (qui, 'PROPN', 'qui', 'PERSON'),
#  (dolorem, 'PROPN', 'dolorem', 'PERSON'),
#  (ipsum, 'PROPN', 'ipsum', ''),
#  (quia, 'PROPN', 'quia', ''),
#  (dolor, 'PROPN', 'dolor', ''),
#  (sit, 'PROPN', 'sit', ''),
#  (amet, 'NOUN', 'amet', ''),
#  (consectetur, 'PROPN', 'consectetur', 'GPE'),
#  (adipisci, 'PROPN', 'adipisci', 'PERSON'),
#  (velit, 'VERB', 'velit', 'PERSON'),
#  (loves, 'VERB', 'love', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (seeks, 'VERB', 'seek', ''),
#  (wants, 'VERB', 'want', ''),
#  (simply, 'ADV', 'simply', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (      , 'SPACE', '      ', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (simply, 'ADV', 'simply', ''),
#  (dummy, 'ADJ', 'dummy', ''),
#  (text, 'NOUN', 'text', ''),
#  (printing, 'NOUN', 'printing', ''),
#  (typesetting, 'VERB', 'typeset', ''),
#  (industry, 'NOUN', 'industry', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (industry, 'NOUN', 'industry', ''),
#  (standard, 'ADJ', 'standard', ''),
#  (dummy, 'ADJ', 'dummy', ''),
#  (text, 'NOUN', 'text', ''),
#  (1500s, 'NOUN', '1500', 'DATE'),
#  (unknown, 'ADJ', 'unknown', ''),
#  (printer, 'NOUN', 'printer', ''),
#  (took, 'VERB', 'take', ''),
#  (galley, 'NOUN', 'galley', ''),
#  (type, 'NOUN', 'type', ''),
#  (scrambled, 'VERB', 'scramble', ''),
#  (type, 'NOUN', 'type', ''),
#  (specimen, 'NOUN', 'speciman', ''),
#  (book, 'NOUN', 'book', ''),
#  (survived, 'VERB', 'survive', ''),
#  (centuries, 'NOUN', 'century', 'DATE'),
#  (leap, 'NOUN', 'leap', ''),
#  (electronic, 'ADJ', 'electronic', ''),
#  (typesetting, 'NOUN', 'typesetting', ''),
#  (remaining, 'VERB', 'remain', ''),
#  (essentially, 'ADV', 'essentially', ''),
#  (unchanged, 'ADJ', 'unchanged', ''),
#  (popularised, 'VERB', 'popularise', ''),
#  (1960s, 'NOUN', '1960', 'DATE'),
#  (release, 'NOUN', 'release', ''),
#  (Letraset, 'PROPN', 'Letraset', 'ORG'),
#  (sheets, 'NOUN', 'sheet', ''),
#  (containing, 'VERB', 'contain', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (passages, 'NOUN', 'passage', ''),
#  (recently, 'ADV', 'recently', ''),
#  (desktop, 'ADJ', 'desktop', ''),
#  (publishing, 'NOUN', 'publishing', ''),
#  (software, 'NOUN', 'software', ''),
#  (like, 'ADP', 'like', ''),
#  (Aldus, 'PROPN', 'Aldus', 'ORG'),
#  (PageMaker, 'PROPN', 'PageMaker', 'PRODUCT'),
#  (including, 'VERB', 'include', ''),
#  (versions, 'NOUN', 'version', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (use, 'VERB', 'use', ''),
#  (long, 'ADV', 'long', ''),
#  (established, 'VERB', 'establish', ''),
#  (fact, 'NOUN', 'fact', ''),
#  (reader, 'NOUN', 'reader', ''),
#  (distracted, 'VERB', 'distract', ''),
#  (readable, 'ADJ', 'readable', ''),
#  (content, 'NOUN', 'content', ''),
#  (page, 'NOUN', 'page', ''),
#  (looking, 'VERB', 'look', ''),
#  (layout, 'NOUN', 'layout', ''),
#  (point, 'NOUN', 'point', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (normal, 'ADJ', 'normal', ''),
#  (distribution, 'NOUN', 'distribution', ''),
#  (letters, 'NOUN', 'letter', ''),
#  (opposed, 'VERB', 'oppose', ''),
#  (Content, 'PROPN', 'Content', ''),
#  (content, 'NOUN', 'content', ''),
#  (making, 'VERB', 'make', ''),
#  (look, 'VERB', 'look', ''),
#  (like, 'ADP', 'like', ''),
#  (readable, 'ADJ', 'readable', ''),
#  (English, 'PROPN', 'English', 'LANGUAGE'),
#  (desktop, 'NOUN', 'desktop', ''),
#  (publishing, 'NOUN', 'publishing', ''),
#  (packages, 'NOUN', 'package', ''),
#  (web, 'NOUN', 'web', ''),
#  (page, 'NOUN', 'page', ''),
#  (editors, 'NOUN', 'editor', ''),
#  (use, 'VERB', 'use', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (default, 'NOUN', 'default', ''),
#  (model, 'NOUN', 'model', ''),
#  (text, 'NOUN', 'text', ''),
#  (search, 'NOUN', 'search', ''),
#  (lorem, 'VERB', 'lorem', ''),
#  (ipsum, 'NOUN', 'ipsum', ''),
#  (uncover, 'VERB', 'uncover', ''),
#  (web, 'NOUN', 'web', ''),
#  (sites, 'NOUN', 'site', ''),
#  (infancy, 'NOUN', 'infancy', ''),
#  (versions, 'NOUN', 'version', ''),
#  (evolved, 'VERB', 'evolve', ''),
#  (years, 'NOUN', 'year', 'DATE'),
#  (accident, 'NOUN', 'accident', ''),
#  (purpose, 'NOUN', 'purpose', ''),
#  (injected, 'VERB', 'inject', ''),
#  (humour, 'NOUN', 'humour', ''),
#  (like, 'ADJ', 'like', ''),
#  (come, 'VERB', 'come', ''),
#  (Contrary, 'ADJ', 'contrary', ''),
#  (popular, 'ADJ', 'popular', ''),
#  (belief, 'NOUN', 'belief', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (simply, 'ADV', 'simply', ''),
#  (random, 'ADJ', 'random', ''),
#  (text, 'NOUN', 'text', ''),
#  (roots, 'NOUN', 'root', ''),
#  (piece, 'NOUN', 'piece', ''),
#  (classical, 'ADJ', 'classical', ''),
#  (Latin, 'PROPN', 'Latin', 'NORP'),
#  (literature, 'NOUN', 'literature', ''),
#  (45, 'NUM', '45', 'CARDINAL'),
#  (BC, 'PROPN', 'BC', 'ORG'),
#  (making, 'VERB', 'make', ''),
#  (2000, 'NUM', '2000', 'DATE'),
#  (years, 'NOUN', 'year', 'DATE'),
#  (old, 'ADJ', 'old', 'DATE'),
#  (Richard, 'PROPN', 'Richard', 'PERSON'),
#  (McClintock, 'PROPN', 'McClintock', 'PERSON'),
#  (Latin, 'ADJ', 'latin', 'NORP'),
#  (professor, 'NOUN', 'professor', ''),
#  (Hampden, 'PROPN', 'Hampden', 'ORG'),
#  (Sydney, 'PROPN', 'Sydney', 'ORG'),
#  (College, 'PROPN', 'College', 'ORG'),
#  (Virginia, 'PROPN', 'Virginia', 'GPE'),
#  (looked, 'VERB', 'look', ''),
#  (obscure, 'ADJ', 'obscure', ''),
#  (Latin, 'ADJ', 'latin', 'NORP'),
#  (words, 'NOUN', 'word', ''),
#  (consectetur, 'PROPN', 'consectetur', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (passage, 'NOUN', 'passage', ''),
#  (going, 'VERB', 'go', ''),
#  (cites, 'NOUN', 'cite', ''),
#  (word, 'NOUN', 'word', ''),
#  (classical, 'ADJ', 'classical', ''),
#  (literature, 'NOUN', 'literature', ''),
#  (discovered, 'VERB', 'discover', ''),
#  (undoubtable, 'ADJ', 'undoubtable', ''),
#  (source, 'NOUN', 'source', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (comes, 'VERB', 'come', ''),
#  (sections, 'NOUN', 'section', ''),
#  (1.10.32, 'ADJ', '1.10.32', 'CARDINAL'),
#  (1.10.33, 'PROPN', '1.10.33', ''),
#  (de, 'PROPN', 'de', ''),
#  (Finibus, 'PROPN', 'Finibus', ''),
#  (Bonorum, 'PROPN', 'Bonorum', ''),
#  (et, 'NOUN', 'et', ''),
#  (Malorum, 'PROPN', 'Malorum', ''),
#  (Extremes, 'PROPN', 'Extremes', 'WORK_OF_ART'),
#  (Good, 'PROPN', 'Good', 'WORK_OF_ART'),
#  (Evil, 'PROPN', 'Evil', 'WORK_OF_ART'),
#  (Cicero, 'PROPN', 'Cicero', 'ORG'),
#  (written, 'VERB', 'write', ''),
#  (45, 'NUM', '45', 'CARDINAL'),
#  (BC, 'PROPN', 'BC', 'ORG'),
#  (book, 'NOUN', 'book', ''),
#  (treatise, 'NOUN', 'treatise', ''),
#  (theory, 'NOUN', 'theory', ''),
#  (ethics, 'NOUN', 'ethic', ''),
#  (popular, 'ADJ', 'popular', ''),
#  (Renaissance, 'PROPN', 'Renaissance', 'ORG'),
#  (line, 'NOUN', 'line', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (ipsum, 'VERB', 'ipsum', ''),
#  (dolor, 'PROPN', 'dolor', ''),
#  (sit, 'PROPN', 'sit', ''),
#  (amet, 'NOUN', 'amet', ''),
#  (comes, 'VERB', 'come', ''),
#  (line, 'NOUN', 'line', ''),
#  (section, 'NOUN', 'section', ''),
#  (1.10.32.The, 'NUM', '1.10.32.the', ''),
#  (standard, 'ADJ', 'standard', ''),
#  (chunk, 'NOUN', 'chunk', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (1500s, 'NUM', '1500s', 'DATE'),
#  (reproduced, 'VERB', 'reproduce', ''),
#  (interested, 'ADJ', 'interested', ''),
#  (Sections, 'NOUN', 'section', ''),
#  (1.10.32, 'PROPN', '1.10.32', 'CARDINAL'),
#  (1.10.33, 'PROPN', '1.10.33', ''),
#  (de, 'X', 'de', ''),
#  (Finibus, 'PROPN', 'Finibus', ''),
#  (Bonorum, 'PROPN', 'Bonorum', ''),
#  (et, 'NOUN', 'et', ''),
#  (Malorum, 'PROPN', 'Malorum', ''),
#  (Cicero, 'PROPN', 'Cicero', 'ORG'),
#  (reproduced, 'VERB', 'reproduce', ''),
#  (exact, 'ADJ', 'exact', ''),
#  (original, 'ADJ', 'original', ''),
#  (form, 'NOUN', 'form', ''),
#  (accompanied, 'VERB', 'accompany', ''),
#  (English, 'ADJ', 'english', 'LANGUAGE'),
#  (versions, 'NOUN', 'version', ''),
#  (1914, 'NUM', '1914', 'DATE'),
#  (translation, 'NOUN', 'translation', ''),
#  (H., 'PROPN', 'H.', 'PERSON'),
#  (Rackham, 'PROPN', 'Rackham', 'PERSON'),
#  (variations, 'NOUN', 'variation', ''),
#  (passages, 'NOUN', 'passage', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (available, 'ADJ', 'available', ''),
#  (majority, 'NOUN', 'majority', ''),
#  (suffered, 'VERB', 'suffer', ''),
#  (alteration, 'NOUN', 'alteration', ''),
#  (form, 'NOUN', 'form', ''),
#  (injected, 'VERB', 'inject', ''),
#  (humour, 'NOUN', 'humour', ''),
#  (randomised, 'VERB', 'randomise', ''),
#  (words, 'NOUN', 'word', ''),
#  (look, 'VERB', 'look', ''),
#  (slightly, 'ADV', 'slightly', ''),
#  (believable, 'ADJ', 'believable', ''),
#  (going, 'VERB', 'go', ''),
#  (use, 'VERB', 'use', ''),
#  (passage, 'NOUN', 'passage', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (need, 'VERB', 'need', ''),
#  (sure, 'ADJ', 'sure', ''),
#  (embarrassing, 'ADJ', 'embarrassing', ''),
#  (hidden, 'VERB', 'hide', ''),
#  (middle, 'NOUN', 'middle', ''),
#  (text, 'NOUN', 'text', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (generators, 'NOUN', 'generator', ''),
#  (Internet, 'NOUN', 'internet', ''),
#  (tend, 'VERB', 'tend', ''),
#  (repeat, 'VERB', 'repeat', ''),
#  (predefined, 'VERB', 'predefine', ''),
#  (chunks, 'NOUN', 'chunk', ''),
#  (necessary, 'ADJ', 'necessary', ''),
#  (making, 'VERB', 'make', ''),
#  (true, 'ADJ', 'true', ''),
#  (generator, 'NOUN', 'generator', ''),
#  (Internet, 'NOUN', 'internet', ''),
#  (uses, 'VERB', 'use', ''),
#  (dictionary, 'NOUN', 'dictionary', ''),
#  (200, 'NUM', '200', 'CARDINAL'),
#  (Latin, 'ADJ', 'latin', 'NORP'),
#  (words, 'NOUN', 'word', ''),
#  (combined, 'VERB', 'combine', ''),
#  (handful, 'NOUN', 'handful', ''),
#  (model, 'NOUN', 'model', ''),
#  (sentence, 'NOUN', 'sentence', ''),
#  (structures, 'NOUN', 'structure', ''),
#  (generate, 'VERB', 'generate', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (looks, 'VERB', 'look', ''),
#  (reasonable, 'ADJ', 'reasonable', ''),
#  (generated, 'VERB', 'generate', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (free, 'ADJ', 'free', ''),
#  (repetition, 'NOUN', 'repetition', ''),
#  (injected, 'VERB', 'inject', ''),
#  (humour, 'NOUN', 'humour', ''),
#  (non, 'ADJ', 'non', ''),
#  (-, 'ADJ', '-', ''),
#  (characteristic, 'ADJ', 'characteristic', ''),
#  (words, 'NOUN', 'word', ''),
#  (etc, 'X', 'etc', ''),
#  (., 'X', '.', ''),
#  (paragraphswordsbyteslistsStart,
#   'NOUN',
#   'paragraphswordsbyteslistsstart',
#   ''),
#  (Loremipsum, 'PROPN', 'Loremipsum', 'PERSON'),
#  (dolor, 'PROPN', 'dolor', ''),
#  (sit, 'PROPN', 'sit', ''),
#  (amet, 'NOUN', 'amet', ''),
#  (Donate, 'VERB', 'donate', ''),
#  (use, 'VERB', 'use', ''),
#  (site, 'NOUN', 'site', ''),
#  (regularly, 'ADV', 'regularly', ''),
#  (like, 'VERB', 'like', ''),
#  (help, 'VERB', 'help', ''),
#  (site, 'NOUN', 'site', ''),
#  (Internet, 'NOUN', 'internet', ''),
#  (consider, 'VERB', 'consider', ''),
#  (donating, 'VERB', 'donate', ''),
#  (small, 'ADJ', 'small', ''),
#  (sum, 'NOUN', 'sum', ''),
#  (help, 'VERB', 'help', ''),
#  (pay, 'VERB', 'pay', ''),
#  (hosting, 'NOUN', 'hosting', ''),
#  (bandwidth, 'ADJ', 'bandwidth', ''),
#  (bill, 'NOUN', 'bill', ''),
#  (minimum, 'NOUN', 'minimum', ''),
#  (donation, 'NOUN', 'donation', ''),
#  (sum, 'NOUN', 'sum', ''),
#  (appreciated, 'VERB', 'appreciate', ''),
#  (click, 'VERB', 'click', ''),
#  (donate, 'VERB', 'donate', ''),
#  (PayPal, 'PROPN', 'PayPal', 'ORG'),
#  (Thank, 'VERB', 'thank', ''),
#  (support, 'NOUN', 'support', ''),
#  (Donate, 'VERB', 'donate', ''),
#  (bitcoin, 'NOUN', 'bitcoin', ''),
#  (16UQLq1HZ3CNwhvgrarV6pMoA2CDjb4tyF,
#   'NUM',
#   '16uqlq1hz3cnwhvgrarv6pmoa2cdjb4tyf',
#   'CARDINAL'),
#  (Translations, 'NOUN', 'translation', ''),
#  (help, 'VERB', 'help', ''),
#  (translate, 'VERB', 'translate', ''),
#  (site, 'NOUN', 'site', ''),
#  (foreign, 'ADJ', 'foreign', ''),
#  (language, 'NOUN', 'language', ''),
#  (email, 'VERB', 'email', ''),
#  (details, 'NOUN', 'detail', ''),
#  (help, 'VERB', 'help', ''),
#  (set, 'NOUN', 'set', ''),
#  (mock, 'ADJ', 'mock', ''),
#  (banners, 'NOUN', 'banner', ''),
#  (available, 'ADJ', 'available', ''),
#  (colours, 'NOUN', 'colour', ''),
#  (range, 'NOUN', 'range', ''),
#  (standard, 'ADJ', 'standard', ''),
#  (banner, 'NOUN', 'banner', ''),
#  (sizes, 'NOUN', 'size', ''),
#  (NodeJS, 'PROPN', 'NodeJS', ''),
#  (Python, 'PROPN', 'Python', ''),
#  (Interface, 'PROPN', 'Interface', ''),
#  (GTK, 'PROPN', 'GTK', ''),
#  (Lipsum, 'PROPN', 'Lipsum', 'PERSON'),
#  (Rails, 'PROPN', 'Rails', 'PERSON'),
#  (   , 'SPACE', '   ', ''),
#  (standard, 'ADJ', 'standard', ''),
#  (Lorem, 'PROPN', 'Lorem', 'PERSON'),
#  (Ipsum, 'PROPN', 'Ipsum', 'PERSON'),
#  (passage, 'NOUN', 'passage', ''),
#  (1500s"Lorem, 'NUM', '1500s"lorem', 'DATE'),
#  (ipsum, 'PROPN', 'ipsum', ''),
#  (dolor, 'PROPN', 'dolor', ''),
#  (sit, 'PROPN', 'sit', ''),
#  (amet, 'NOUN', 'amet', ''),
#  (consectetur, 'VERB', 'consectetur', ''),
#  (adipiscing, 'VERB', 'adipisce', ''),
#  (elit, 'NOUN', 'elit', ''),
#  (sed, 'VERB', 'se', ''),
#  (eiusmod, 'PROPN', 'eiusmod', ''),
#  (tempor, 'PROPN', 'tempor', ''),
#  (incididunt, 'PROPN', 'incididunt', ''),
#  (ut, 'PROPN', 'ut', ''),
#  (labore, 'PROPN', 'labore', ''),
#  (et, 'PROPN', 'et', ''),
#  (dolore, 'NOUN', 'dolore', ''),
#  (magna, 'PROPN', 'magna', ''),
#  (aliqua, 'NOUN', 'aliqua', ''),
#  (Ut, 'INTJ', 'ut', ''),
#  (enim, 'NOUN', 'enim', ''),
#  (ad, 'NOUN', 'ad', ''),
#  (minim, 'NOUN', 'minim', 'PERSON'),
#  (veniam, 'PROPN', 'veniam', 'PERSON'),
#  (quis, 'PROPN', 'quis', ''),
#  (nostrud, 'PROPN', 'nostrud', ''),
#  (exercitation, 'PROPN', 'exercitation', ''),
#  (ullamco, 'PROPN', 'ullamco', ''),
#  (laboris, 'PROPN', 'laboris', 'PERSON'),
#  (nisi, 'PROPN', 'nisi', 'PERSON'),
#  (ut, 'PROPN', 'ut', ''),
#  (aliquip, 'PROPN', 'aliquip', ''),
#  (ex, 'PROPN', 'ex', ''),
#  (ea, 'PROPN', 'ea', ''),
#  (commodo, 'NOUN', 'commodo', ''),
#  (consequat, 'NOUN', 'consequat', ''),
#  (Duis, 'PROPN', 'Duis', 'PERSON'),
#  (aute, 'PROPN', 'aute', ''),
#  (irure, 'PROPN', 'irure', ''),
#  (dolor, 'PROPN', 'dolor', ''),
#  (reprehenderit, 'NOUN', 'reprehenderit', ''),
#  (voluptate, 'ADJ', 'voluptate', ''),
#  (velit, 'PROPN', 'velit', ''),
#  (esse, 'PROPN', 'esse', ''),
#  (cillum, 'PROPN', 'cillum', ''),
#  (dolore, 'PROPN', 'dolore', ''),
#  (eu, 'PROPN', 'eu', 'PERSON'),
#  (fugiat, 'PROPN', 'fugiat', ''),
#  (nulla, 'PROPN', 'nulla', ''),
#  (pariatur, 'NOUN', 'pariatur', ''),
#  (Excepteur, 'PROPN', 'Excepteur', ''),
#  (sint, 'NOUN', 'sint', ''),
#  (occaecat, 'ADP', 'occaecat', ''),
#  (cupidatat, 'PROPN', 'cupidatat', ''),
#  (non, 'PROPN', 'non', ''),
#  (proident, 'PROPN', 'proident', ''),
#  (sunt, 'PROPN', 'sunt', ''),
#  (culpa, 'PROPN', 'culpa', ''),
#  (qui, 'PROPN', 'qui', 'PERSON'),
#  (officia, 'PROPN', 'officia', 'PERSON'),
#  (deserunt, 'PROPN', 'deserunt', 'PERSON'),
#  (mollit, 'PROPN', 'mollit', ''),
#  (anim, 'PROPN', 'anim', ''),
#  (d, 'PROPN', 'd', ''),
#  (est, 'X', 'est', ''),
#  (laborum, 'NOUN', 'laborum', ''),
#  ("Section, 'NOUN', '"section', ''),
#  (1.10.32, 'ADJ', '1.10.32', 'CARDINAL'),
#  (de, 'PROPN', 'de', ''),
#  (Finibus, 'PROPN', 'Finibus', ''),
#  (Bonorum, 'PROPN', 'Bonorum', ''),
#  (et, 'NOUN', 'et', ''),
#  (Malorum, 'PROPN', 'Malorum', ''),
#  (written, 'VERB', 'write', ''),
#  (Cicero, 'PROPN', 'Cicero', 'ORG'),
#  (45, 'NUM', '45', 'CARDINAL'),
#  (BC"Sed, 'NOUN', 'bc"sed', ''),
#  (ut, 'ADP', 'ut', ''),
#  (perspiciatis, 'NOUN', 'perspiciatis', ''),
#  (unde, 'PROPN', 'unde', ''),
#  (omnis, 'PROPN', 'omnis', ''),
#  (iste, 'VERB', 'iste', ''),
#  (natus, 'PROPN', 'natus', ''),
#  (error, 'NOUN', 'error', ''),
#  (sit, 'VERB', 'sit', ''),
#  (voluptatem, 'NOUN', 'voluptatem', ''),
#  (accusantium, 'NOUN', 'accusantium', ''),
#  (doloremque, 'ADJ', 'doloremque', ''),
#  (laudantium, 'NOUN', 'laudantium', ''),
#  (totam, 'PROPN', 'totam', 'PERSON'),
#  (rem, 'PROPN', 'rem', 'PERSON'),
#  (aperiam, 'PROPN', 'aperiam', 'PERSON'),
#  (eaque, 'ADJ', 'eaque', 'NORP'),
#  (ipsa, 'PROPN', 'ipsa', ''),
#  (quae, 'PROPN', 'quae', 'GPE'),
#  (ab, 'PROPN', 'ab', ''),
#  (illo, 'PROPN', 'illo', 'ORG'),
#  (inventore, 'PROPN', 'inventore', ''),
#  (veritatis, 'PROPN', 'veritatis', ''),
#  (et, 'PROPN', 'et', ''),
#  (quasi, 'X', 'quasi', ''),
#  (architecto, 'X', 'architecto', ''),
#  (beatae, 'PROPN', 'beatae', ''),
#  (vitae, 'PROPN', 'vitae', ''),
#  (dicta, 'VERB', 'dicta', ''),
#  (sunt, 'PROPN', 'sunt', ''),
#  (explicabo, 'PROPN', 'explicabo', ''),
#  (Nemo, 'PROPN', 'Nemo', ''),
#  (enim, 'PROPN', 'enim', ''),
#  (ipsam, 'PROPN', 'ipsam', ''),
#  (voluptatem, 'NOUN', 'voluptatem', ''),
#  (quia, 'NOUN', 'quia', ''),
#  (voluptas, 'NOUN', 'volupta', ''),
#  (sit, 'VERB', 'sit', ''),
#  (aspernatur, 'NOUN', 'aspernatur', ''),
#  (aut, 'NOUN', 'aut', ''),
#  (odit, 'NOUN', 'odit', ''),
#  (aut, 'NOUN', 'aut', 'PERSON'),
#  (fugit, 'ADJ', 'fugit', 'PERSON'),
#  (sed, 'VERB', 'se', ''),
#  (quia, 'NOUN', 'quia', 'ORG'),
#  (consequuntur, 'VERB', 'consequuntur', 'ORG'),
#  (magni, 'NOUN', 'magni', 'ORG'),
#  (dolores, 'NOUN', 'dolore', ''),
#  (eos, 'VERB', 'eos', 'ORG'),
#  (qui, 'PROPN', 'qui', 'ORG'),
#  (ratione, 'NOUN', 'ratione', ''),
#  (voluptatem, 'NOUN', 'voluptatem', ''),
#  (sequi, 'NOUN', 'sequi', ''),
#  (nesciunt, 'NOUN', 'nesciunt', ''),
#  (Neque, 'PROPN', 'Neque', 'PERSON'),
#  (porro, 'PROPN', 'porro', ''),
#  (quisquam, 'VERB', 'quisquam', ''),
#  (est, 'PROPN', 'est', ''),
#  (qui, 'PROPN', 'qui', 'ORG'),
#  (dolorem, 'PROPN', 'dolorem', 'ORG'),
#  (ipsum, 'PROPN', 'ipsum', ''),
#  (quia, 'PROPN', 'quia', ''),
#  (dolor, 'PROPN', 'dolor', ''),
#  (sit, 'PROPN', 'sit', ''),
#  (amet, 'NOUN', 'amet', ''),
#  (consectetur, 'PROPN', 'consectetur', 'GPE'),
#  (adipisci, 'PROPN', 'adipisci', 'PERSON'),
#  (velit, 'PROPN', 'velit', 'PERSON'),
#  (sed, 'VERB', 'se', ''),
#  (quia, 'NOUN', 'quia', ''),
#  (non, 'PROPN', 'non', ''),
#  (numquam, 'PROPN', 'numquam', ''),
#  (eius, 'PROPN', 'eius', ''),
#  (modi, 'PROPN', 'modi', ''),
#  (tempora, 'PROPN', 'tempora', 'PERSON'),
#  (incidunt, 'PROPN', 'incidunt', 'PERSON'),
#  (ut, 'INTJ', 'ut', ''),
#  (labore, 'PROPN', 'labore', ''),
#  (et, 'PROPN', 'et', ''),
#  (dolore, 'PROPN', 'dolore', ''),
#  (magnam, 'PROPN', 'magnam', ''),
#  (aliquam, 'PROPN', 'aliquam', ''),
#  (quaerat, 'PROPN', 'quaerat', ''),
#  (voluptatem, 'NOUN', 'voluptatem', ''),
#  (Ut, 'ADP', 'ut', ''),
#  (enim, 'NOUN', 'enim', ''),
#  (ad, 'NOUN', 'ad', ''),
#  (minima, 'PROPN', 'minima', 'PERSON'),
#  (veniam, 'PROPN', 'veniam', 'PERSON'),
#  (quis, 'PROPN', 'quis', ''),
#  (nostrum, 'PROPN', 'nostrum', ''),
#  (exercitationem, 'PROPN', 'exercitationem', ''),
#  (ullam, 'PROPN', 'ullam', ''),
#  (corporis, 'PROPN', 'corporis', ''),
#  (suscipit, 'PROPN', 'suscipit', 'PERSON'),
#  (laboriosam, 'PROPN', 'laboriosam', 'PERSON'),
#  (nisi, 'PROPN', 'nisi', 'PERSON'),
#  (ut, 'PROPN', 'ut', ''),
#  (aliquid, 'PROPN', 'aliquid', ''),
#  (ex, 'PROPN', 'ex', ''),
#  (ea, 'X', 'ea', ''),
#  (commodi, 'ADV', 'commodi', ''),
#  (consequatur, 'NOUN', 'consequatur', ''),
#  (Quis, 'NOUN', 'quis', ''),
#  (autem, 'NOUN', 'autem', ''),
#  (vel, 'PROPN', 'vel', ''),
#  (eum, 'PROPN', 'eum', ''),
#  (iure, 'PROPN', 'iure', ''),
#  (reprehenderit, 'PROPN', 'reprehenderit', ''),
#  (qui, 'PROPN', 'qui', ''),
#  (ea, 'PROPN', 'ea', ''),
#  (voluptate, 'ADJ', 'voluptate', ''),
#  (velit, 'PROPN', 'velit', ''),
#  (esse, 'PROPN', 'esse', ''),
#  (quam, 'PROPN', 'quam', 'PERSON'),
#  (nihil, 'PROPN', 'nihil', 'PERSON'),
#  (molestiae, 'PROPN', 'molestiae', 'PERSON'),
#  (consequatur, 'PROPN', 'consequatur', 'PERSON'),
#  (vel, 'PROPN', 'vel', ''),
#  (illum, 'PROPN', 'illum', ''),
#  (qui, 'PROPN', 'qui', 'PERSON'),
#  (dolorem, 'PROPN', 'dolorem', 'PERSON'),
#  (eum, 'PROPN', 'eum', ''),
#  (fugiat, 'PROPN', 'fugiat', ''),
#  (quo, 'NOUN', 'quo', ''),
#  (voluptas, 'NOUN', 'volupta', ''),
#  (nulla, 'NOUN', 'nulla', ''),
#  (pariatur, 'NOUN', 'pariatur', ''),
#  (1914, 'NUM', '1914', 'DATE'),
#  (translation, 'NOUN', 'translation', ''),
#  (H., 'PROPN', 'H.', 'PERSON'),
#  (Rackham, 'PROPN', 'Rackham', 'PERSON'),
#  (explain, 'VERB', 'explain', ''),
#  (mistaken, 'ADJ', 'mistaken', ''),
#  (idea, 'NOUN', 'idea', ''),
#  (denouncing, 'VERB', 'denounce', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (praising, 'VERB', 'praise', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (born, 'VERB', 'bear', ''),
#  (complete, 'ADJ', 'complete', ''),
#  (account, 'NOUN', 'account', ''),
#  (system, 'NOUN', 'system', ''),
#  (expound, 'VERB', 'expound', ''),
#  (actual, 'ADJ', 'actual', ''),
#  (teachings, 'NOUN', 'teaching', ''),
#  (great, 'ADJ', 'great', ''),
#  (explorer, 'NOUN', 'explorer', ''),
#  (truth, 'NOUN', 'truth', ''),
#  (master, 'NOUN', 'master', ''),
#  (builder, 'NOUN', 'builder', ''),
#  (human, 'ADJ', 'human', ''),
#  (happiness, 'NOUN', 'happiness', ''),
#  (rejects, 'NOUN', 'reject', ''),
#  (dislikes, 'PROPN', 'dislikes', ''),
#  (avoids, 'VERB', 'avoid', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (know, 'VERB', 'know', ''),
#  (pursue, 'VERB', 'pursue', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (rationally, 'ADV', 'rationally', ''),
#  (encounter, 'VERB', 'encounter', ''),
#  (consequences, 'NOUN', 'consequence', ''),
#  (extremely, 'ADV', 'extremely', ''),
#  (painful, 'ADJ', 'painful', ''),
#  (loves, 'VERB', 'love', ''),
#  (pursues, 'NOUN', 'pursue', ''),
#  (desires, 'NOUN', 'desire', ''),
#  (obtain, 'VERB', 'obtain', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (occasionally, 'ADV', 'occasionally', ''),
#  (circumstances, 'NOUN', 'circumstance', ''),
#  (occur, 'VERB', 'occur', ''),
#  (toil, 'NOUN', 'toil', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (procure, 'VERB', 'procure', ''),
#  (great, 'ADJ', 'great', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (trivial, 'ADJ', 'trivial', ''),
#  (example, 'NOUN', 'example', ''),
#  (undertakes, 'VERB', 'undertake', ''),
#  (laborious, 'ADJ', 'laborious', ''),
#  (physical, 'ADJ', 'physical', ''),
#  (exercise, 'NOUN', 'exercise', ''),
#  (obtain, 'VERB', 'obtain', ''),
#  (advantage, 'NOUN', 'advantage', ''),
#  (right, 'NOUN', 'right', ''),
#  (find, 'VERB', 'find', ''),
#  (fault, 'NOUN', 'fault', ''),
#  (man, 'NOUN', 'man', ''),
#  (chooses, 'VERB', 'choose', ''),
#  (enjoy, 'VERB', 'enjoy', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (annoying, 'ADJ', 'annoying', ''),
#  (consequences, 'NOUN', 'consequence', ''),
#  (avoids, 'VERB', 'avoid', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (produces, 'VERB', 'produce', ''),
#  (resultant, 'ADJ', 'resultant', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (Section, 'NOUN', 'section', ''),
#  (1.10.33, 'PROPN', '1.10.33', ''),
#  (de, 'PROPN', 'de', ''),
#  (Finibus, 'PROPN', 'Finibus', ''),
#  (Bonorum, 'PROPN', 'Bonorum', ''),
#  (et, 'NOUN', 'et', ''),
#  (Malorum, 'PROPN', 'Malorum', ''),
#  (written, 'VERB', 'write', ''),
#  (Cicero, 'PROPN', 'Cicero', 'ORG'),
#  (45, 'NUM', '45', 'CARDINAL'),
#  (BC, 'PROPN', 'BC', 'ORG'),
#  (vero, 'NOUN', 'vero', 'ORG'),
#  (eos, 'PROPN', 'eos', ''),
#  (et, 'PROPN', 'et', ''),
#  (accusamus, 'PROPN', 'accusamus', ''),
#  (et, 'PROPN', 'et', ''),
#  (iusto, 'PROPN', 'iusto', ''),
#  (odio, 'PROPN', 'odio', ''),
#  (dignissimos, 'PROPN', 'dignissimos', ''),
#  (ducimus, 'PROPN', 'ducimus', 'PERSON'),
#  (qui, 'PROPN', 'qui', 'PERSON'),
#  (blanditiis, 'PROPN', 'blanditiis', 'PERSON'),
#  (praesentium, 'NOUN', 'praesentium', ''),
#  (voluptatum, 'NOUN', 'voluptatum', ''),
#  (deleniti, 'PROPN', 'deleniti', ''),
#  (atque, 'ADJ', 'atque', ''),
#  (corrupti, 'PROPN', 'corrupti', ''),
#  (quos, 'NOUN', 'quo', ''),
#  (dolores, 'NOUN', 'dolore', ''),
#  (et, 'PROPN', 'et', ''),
#  (quas, 'PROPN', 'quas', ''),
#  (molestias, 'PROPN', 'molestias', ''),
#  (excepturi, 'PROPN', 'excepturi', 'ORG'),
#  (sint, 'PROPN', 'sint', 'ORG'),
#  (occaecati, 'PROPN', 'occaecati', 'PRODUCT'),
#  (cupiditate, 'PROPN', 'cupiditate', ''),
#  (non, 'PROPN', 'non', 'ORG'),
#  (provident, 'PROPN', 'provident', 'ORG'),
#  (similique, 'ADJ', 'similique', ''),
#  (sunt, 'PROPN', 'sunt', ''),
#  (culpa, 'PROPN', 'culpa', ''),
#  (qui, 'PROPN', 'qui', 'PERSON'),
#  (officia, 'PROPN', 'officia', 'PERSON'),
#  (deserunt, 'PROPN', 'deserunt', 'PERSON'),
#  (mollitia, 'PROPN', 'mollitia', 'PERSON'),
#  (animi, 'PROPN', 'animi', 'PERSON'),
#  (d, 'PROPN', 'd', ''),
#  (est, 'X', 'est', ''),
#  (laborum, 'NOUN', 'laborum', ''),
#  (et, 'PROPN', 'et', ''),
#  (dolorum, 'NOUN', 'dolorum', ''),
#  (fuga, 'NOUN', 'fuga', ''),
#  (Et, 'INTJ', 'et', ''),
#  (harum, 'ADP', 'harum', ''),
#  (quidem, 'PROPN', 'quidem', 'GPE'),
#  (rerum, 'PROPN', 'rerum', ''),
#  (facilis, 'PROPN', 'facilis', ''),
#  (est, 'X', 'est', ''),
#  (et, 'NOUN', 'et', ''),
#  (expedita, 'NOUN', 'expedita', ''),
#  (distinctio, 'NOUN', 'distinctio', ''),
#  (Nam, 'PROPN', 'Nam', ''),
#  (libero, 'NOUN', 'libero', ''),
#  (tempore, 'PROPN', 'tempore', ''),
#  (cum, 'PROPN', 'cum', ''),
#  (soluta, 'PROPN', 'soluta', ''),
#  (nobis, 'X', 'nobis', ''),
#  (est, 'X', 'est', ''),
#  (eligendi, 'PROPN', 'eligendi', ''),
#  (optio, 'PROPN', 'optio', ''),
#  (cumque, 'PROPN', 'cumque', ''),
#  (nihil, 'PROPN', 'nihil', ''),
#  (impedit, 'NOUN', 'impedit', ''),
#  (quo, 'NOUN', 'quo', ''),
#  (minus, 'CCONJ', 'minus', ''),
#  (d, 'PROPN', 'd', ''),
#  (quod, 'NOUN', 'quod', ''),
#  (maxime, 'NOUN', 'maxime', ''),
#  (placeat, 'NOUN', 'placeat', ''),
#  (facere, 'ADJ', 'facere', ''),
#  (possimus, 'NOUN', 'possimus', ''),
#  (omnis, 'VERB', 'omni', ''),
#  (voluptas, 'NOUN', 'volupta', ''),
#  (assumenda, 'PROPN', 'assumenda', ''),
#  (est, 'ADJ', 'e', ''),
#  (omnis, 'VERB', 'omni', ''),
#  (dolor, 'PROPN', 'dolor', ''),
#  (repellendus, 'PROPN', 'repellendus', ''),
#  (Temporibus, 'NOUN', 'temporibus', 'ORG'),
#  (autem, 'NOUN', 'autem', ''),
#  (quibusdam, 'NOUN', 'quibusdam', ''),
#  (et, 'PROPN', 'et', ''),
#  (aut, 'PROPN', 'aut', ''),
#  (officiis, 'PROPN', 'officiis', ''),
#  (debitis, 'PROPN', 'debitis', ''),
#  (aut, 'PROPN', 'aut', ''),
#  (rerum, 'PROPN', 'rerum', ''),
#  (necessitatibus, 'NOUN', 'necessitatibus', ''),
#  (saepe, 'PROPN', 'saepe', ''),
#  (eveniet, 'PROPN', 'eveniet', ''),
#  (ut, 'PROPN', 'ut', ''),
#  (et, 'PROPN', 'et', ''),
#  (voluptates, 'VERB', 'voluptate', ''),
#  (repudiandae, 'NOUN', 'repudiandae', ''),
#  (sint, 'NOUN', 'sint', ''),
#  (et, 'PROPN', 'et', ''),
#  (molestiae, 'PROPN', 'molestiae', ''),
#  (non, 'X', 'non', ''),
#  (recusandae, 'NOUN', 'recusandae', ''),
#  (Itaque, 'ADJ', 'itaque', 'NORP'),
#  (earum, 'NOUN', 'earum', ''),
#  (rerum, 'VERB', 'rerum', ''),
#  (hic, 'PROPN', 'hic', ''),
#  (tenetur, 'PROPN', 'tenetur', ''),
#  (sapiente, 'NOUN', 'sapiente', ''),
#  (delectus, 'NOUN', 'delectus', ''),
#  (ut, 'PROPN', 'ut', ''),
#  (aut, 'NOUN', 'aut', ''),
#  (reiciendis, 'VERB', 'reiciendi', ''),
#  (voluptatibus, 'PROPN', 'voluptatibus', 'ORG'),
#  (maiores, 'NOUN', 'maiore', ''),
#  (alias, 'PROPN', 'alias', 'PERSON'),
#  (consequatur, 'PROPN', 'consequatur', 'PERSON'),
#  (aut, 'PROPN', 'aut', ''),
#  (perferendis, 'PROPN', 'perferendis', ''),
#  (doloribus, 'PROPN', 'doloribus', 'ORG'),
#  (asperiores, 'NOUN', 'asperiore', ''),
#  (repellat, 'VERB', 'repellat', ''),
#  (1914, 'NUM', '1914', 'DATE'),
#  (translation, 'NOUN', 'translation', ''),
#  (H., 'PROPN', 'H.', 'PERSON'),
#  (Rackham, 'PROPN', 'Rackham', 'PERSON'),
#  (hand, 'NOUN', 'hand', ''),
#  (denounce, 'VERB', 'denounce', ''),
#  (righteous, 'ADJ', 'righteous', ''),
#  (indignation, 'NOUN', 'indignation', ''),
#  (dislike, 'VERB', 'dislike', ''),
#  (men, 'NOUN', 'man', ''),
#  (beguiled, 'ADJ', 'beguiled', ''),
#  (demoralized, 'VERB', 'demoralize', ''),
#  (charms, 'NOUN', 'charm', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (moment, 'NOUN', 'moment', ''),
#  (blinded, 'VERB', 'blind', ''),
#  (desire, 'NOUN', 'desire', ''),
#  (foresee, 'VERB', 'foresee', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (trouble, 'NOUN', 'trouble', ''),
#  (bound, 'VERB', 'bind', ''),
#  (ensue, 'VERB', 'ensue', ''),
#  (equal, 'ADJ', 'equal', ''),
#  (blame, 'NOUN', 'blame', ''),
#  (belongs, 'VERB', 'belong', ''),
#  (fail, 'VERB', 'fail', ''),
#  (duty, 'NOUN', 'duty', ''),
#  (weakness, 'NOUN', 'weakness', ''),
#  (saying, 'VERB', 'say', ''),
#  (shrinking, 'VERB', 'shrink', ''),
#  (toil, 'NOUN', 'toil', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (cases, 'NOUN', 'case', ''),
#  (perfectly, 'ADV', 'perfectly', ''),
#  (simple, 'ADJ', 'simple', ''),
#  (easy, 'ADJ', 'easy', ''),
#  (distinguish, 'VERB', 'distinguish', ''),
#  (free, 'ADJ', 'free', 'TIME'),
#  (hour, 'NOUN', 'hour', 'TIME'),
#  (power, 'NOUN', 'power', ''),
#  (choice, 'NOUN', 'choice', ''),
#  (untrammelled, 'VERB', 'untrammelle', ''),
#  (prevents, 'VERB', 'prevent', ''),
#  (able, 'ADJ', 'able', ''),
#  (like, 'VERB', 'like', ''),
#  (best, 'ADJ', 'good', ''),
#  (pleasure, 'NOUN', 'pleasure', ''),
#  (welcomed, 'VERB', 'welcome', ''),
#  (pain, 'NOUN', 'pain', ''),
#  (avoided, 'VERB', 'avoid', ''),
#  (certain, 'ADJ', 'certain', ''),
#  (circumstances, 'NOUN', 'circumstance', ''),
#  (owing, 'VERB', 'owe', ''),
#  (claims, 'NOUN', 'claim', ''),
#  (duty, 'NOUN', 'duty', ''),
#  (obligations, 'NOUN', 'obligation', ''),
#  (business, 'NOUN', 'business', ''),
#  (frequently, 'ADV', 'frequently', ''),
#  (occur, 'VERB', 'occur', ''),
#  (pleasures, 'NOUN', 'pleasure', ''),
#  (repudiated, 'VERB', 'repudiate', ''),
#  (annoyances, 'NOUN', 'annoyance', ''),
#  (accepted, 'VERB', 'accept', ''),
#  (wise, 'ADJ', 'wise', ''),
#  (man, 'NOUN', 'man', ''),
#  (holds, 'VERB', 'hold', ''),
#  (matters, 'NOUN', 'matter', ''),
#  (principle, 'NOUN', 'principle', ''),
#  (selection, 'NOUN', 'selection', ''),
#  (rejects, 'VERB', 'reject', ''),
#  (pleasures, 'NOUN', 'pleasure', ''),
#  (secure, 'VERB', 'secure', ''),
#  (greater, 'ADJ', 'great', ''),
#  (pleasures, 'NOUN', 'pleasure', ''),
#  (endures, 'VERB', 'endure', ''),
#  (pains, 'NOUN', 'pain', ''),
#  (avoid, 'VERB', 'avoid', ''),
#  (worse, 'ADJ', 'bad', ''),
#  (pains, 'NOUN', 'pain', ''),
#  (help@lipsum.comPrivacy, 'PROPN', 'help@lipsum.comPrivacy', ''),
#  (Policy, 'PROPN', 'Policy', ''),
#  (Privacy, 'PROPN', 'Privacy', ''),
#  (Manager, 'PROPN', 'Manager', ''),
#  (   , 'SPACE', '   ', '')]

# %% [markdown]
# ##  **ALL THE RELEVENT WORDS WITH ENTITY TYPE**

# %%
for i in dict([(str(x), x.label_) for x in nlp(str(article)).ents]).items():
    print((i[0].replace('  ',''),i[1]))
# Out:
# ('Lorem Ipsum - All', 'PERSON')
# ('Български Català', 'ORG')
# ('Hrvatski Česky Dansk', 'PERSON')
# ('Filipino', 'NORP')
# ('Deutsch Ελληνικά', 'PERSON')
# ('Magyar', 'GPE')
# ('Indonesia', 'GPE')
# ('Српски', 'GPE')
# ('Svenska', 'GPE')
# ('Türkçe Українська', 'PERSON')
# ('Lorem Ipsum', 'PERSON')
# ('qui dolorem', 'PERSON')
# ('consectetur', 'GPE')
# ('adipisci velit', 'PERSON')
# ('the 1500s', 'DATE')
# ('only five centuries', 'DATE')
# ('the 1960s', 'DATE')
# ('Letraset', 'ORG')
# ('Aldus', 'ORG')
# ('PageMaker', 'PRODUCT')
# ('English', 'LANGUAGE')
# ('the years', 'DATE')
# ('Latin', 'NORP')
# ('45', 'CARDINAL')
# ('BC', 'ORG')
# ('2000 years old', 'DATE')
# ('Richard McClintock', 'PERSON')
# ('Hampden-Sydney College', 'ORG')
# ('Virginia', 'GPE')
# ('one', 'CARDINAL')
# ('1.10.32', 'CARDINAL')
# ('The Extremes of Good and Evil', 'WORK_OF_ART')
# ('Cicero', 'ORG')
# ('Renaissance', 'ORG')
# ('first', 'ORDINAL')
# ('Lorem', 'PERSON')
# ('1914', 'DATE')
# ('H. Rackham', 'PERSON')
# ('200', 'CARDINAL')
# ('Loremipsum', 'PERSON')
# ('PayPal', 'ORG')
# ('16UQLq1HZ3CNwhvgrarV6pMoA2CDjb4tyF', 'CARDINAL')
# ('three', 'CARDINAL')
# ('Lipsum Rails', 'PERSON')
# ('1500s"Lorem', 'DATE')
# ('minim veniam', 'PERSON')
# ('laboris nisi', 'PERSON')
# ('Duis', 'PERSON')
# ('eu', 'PERSON')
# ('qui officia deserunt', 'PERSON')
# ('totam rem aperiam', 'PERSON')
# ('eaque', 'NORP')
# ('quae', 'GPE')
# ('illo', 'ORG')
# ('aut fugit', 'PERSON')
# ('quia consequuntur magni', 'ORG')
# ('eos qui', 'ORG')
# ('Neque', 'PERSON')
# ('tempora incidunt', 'PERSON')
# ('minima veniam', 'PERSON')
# ('suscipit laboriosam', 'PERSON')
# ('nisi', 'PERSON')
# ('quam nihil molestiae consequatur', 'PERSON')
# ('vero', 'ORG')
# ('ducimus qui blanditiis', 'PERSON')
# ('excepturi sint', 'ORG')
# ('occaecati', 'PRODUCT')
# ('non provident', 'ORG')
# ('mollitia animi', 'PERSON')
# ('quidem', 'GPE')
# ('Temporibus', 'ORG')
# ('Itaque', 'NORP')
# ('voluptatibus', 'ORG')
# ('alias consequatur', 'PERSON')
# ('doloribus', 'ORG')
# ('a free hour', 'TIME')

# %%
import nlp_preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 import nlp_preprocessing
#
# File ~\anaconda3\lib\site-packages\nlp_preprocessing\__init__.py:4, in <module>
#       2 from .dataset import Dataset
#       3 from .seq_parser_token_generator import SpacyParseTokenizer
# ----> 4 from .seq_token_generator import SpacyTokenizer
#       5 from .vocab_embedding_extractor import VocabEmbeddingExtractor
#       6 from .tokenization import *
#
# File ~\anaconda3\lib\site-packages\nlp_preprocessing\seq_token_generator.py:1, in <module>
# ----> 1 from tensorflow.keras.preprocessing.sequence import pad_sequences
#       2 import spacy
#       3 import deepdish as dd
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:45, in <module>
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from ._api.v2 import __internal__
#      46 from ._api.v2 import __operators__
#      47 from ._api.v2 import audio
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:14, in <module>
#      12 from . import eager_context
#      13 from . import feature_column
# ---> 14 from . import function
#      15 from . import graph_util
#      16 from . import mixed_precision
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\function\__init__.py:8, in <module>
#       3 """Public API for tf.__internal__.function namespace.
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.eager.polymorphic_function.polymorphic_function import Function
#       9 from tensorflow.python.eager.polymorphic_function.quarantine import defun_with_attributes
#
# ModuleNotFoundError: No module named 'tensorflow.python.eager.polymorphic_function'

# %%
# !pip install nlp-preprocessing
# Out:
# Collecting nlp-preprocessing
#   Downloading nlp_preprocessing-0.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: spacy in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from nlp-preprocessing) (3.5.3)
# Requirement already satisfied: gensim in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from nlp-preprocessing) (4.1.2)
# Requirement already satisfied: scikit-learn in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from nlp-preprocessing) (1.0.2)
# Collecting deepdish
#   Downloading deepdish-0.3.7-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from nlp-preprocessing) (1.21.6)
# Requirement already satisfied: tqdm in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from nlp-preprocessing) (4.64.0)
# Requirement already satisfied: tables in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from deepdish->nlp-preprocessing) (3.6.1)
# Requirement already satisfied: scipy in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from deepdish->nlp-preprocessing) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from gensim->nlp-preprocessing) (6.3.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from scikit-learn->nlp-preprocessing) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from scikit-learn->nlp-preprocessing) (2.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (21.3)
# Requirement already satisfied: jinja2 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (3.1.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (61.2.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (8.1.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (2.4.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (1.10.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (3.0.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (1.0.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from spacy->nlp-preprocessing) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from packaging>=20.0->spacy->nlp-preprocessing) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy->nlp-preprocessing) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->nlp-preprocessing) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->nlp-preprocessing) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->nlp-preprocessing) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->nlp-preprocessing) (1.26.9)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy->nlp-preprocessing) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy->nlp-preprocessing) (0.0.4)
# Requirement already satisfied: colorama in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from tqdm->nlp-preprocessing) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy->nlp-preprocessing) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from jinja2->spacy->nlp-preprocessing) (2.0.1)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\smritik sadhukhan\anaconda3\lib\site-packages (from tables->deepdish->nlp-preprocessing) (2.8.1)
# Installing collected packages: deepdish, nlp-preprocessing
# Successfully installed deepdish-0.3.7 nlp-preprocessing-0.2.0
